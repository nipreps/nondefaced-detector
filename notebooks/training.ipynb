# %%
import random
import nobrainer
import os, sys
sys.path.append('..')
import numpy as np
import nibabel as nb
from glob import glob


import defacing
from defacing import dataloaders, training

# %%
import nobrainer
from nobrainer.io import _is_gzipped
from nobrainer.volume import to_blocks
import sys, os
sys.path.append('../')
from defacing.preprocessing.augmentation import VolumeAugmentations, SliceAugmentations
from defacing.helpers.utils import load_vol
import tensorflow as tf
import glob
import numpy as np

AUTOTUNE = tf.data.experimental.AUTOTUNE

def get_dataset(
    file_pattern,
    n_classes,
    batch_size,
    volume_shape,
    plane,
    n_slices = 24,
    block_shape=None,
    n_epochs=None,
    mapping=None,
    shuffle_buffer_size=None,
    num_parallel_calls=AUTOTUNE,
    mode='train',
):

    """ Returns tf.data.Dataset after preprocessing from
    tfrecords for training and validation

    Parameters
    ----------
    file_pattern:

    n_classes:
    """

    files = glob.glob(file_pattern)

    if not files:
        raise ValueError("no files found for pattern '{}'".format(file_pattern))

    compressed = _is_gzipped(files[0])
    shuffle = bool(shuffle_buffer_size)

    ds = nobrainer.dataset.tfrecord_dataset(
        file_pattern=file_pattern,
        volume_shape=volume_shape,
        shuffle=shuffle,
        scalar_label=True,
        compressed=compressed,
        num_parallel_calls=num_parallel_calls,
    )
    
    
    def _ss(x, y):
        
        x, y = structural_slice(x, y, plane, n_slices)
        return (x, y)
    
    
    ds = ds.map(_ss, num_parallel_calls)
        
    ds = ds.prefetch(buffer_size=batch_size)
    
    if batch_size is not None:
        ds = ds.batch(batch_size=batch_size, drop_remainder=True)
        
    if mode == 'train':
        if shuffle_buffer_size:
            ds = ds.shuffle(buffer_size=shuffle_buffer_size)

#         Repeat the dataset n_epochs times
        ds = ds.repeat(n_epochs)

    return ds


def structural_slice(x, y, plane, n_slices = 4):

    """ Transpose dataset based on the plane

    Parameters
    ----------
    x:

    y:

    plane:
    
    n:

    augment:
    """

    options = ["sagittal", "coronal", "axial", "combined"]
    shape = np.array(x.shape)
    if isinstance(plane, str) and plane in options:
        idxs = np.random.randint(x.shape[0], size=(n_slices, 3))
#         idxs = np.array([[64, 64, 64]])
        if plane == "sagittal":
            midx = idxs[:, 0]
            x = x

        if plane == "coronal":
            midx = idxs[:, 1]
            x = tf.transpose(x, perm=[1, 2, 0])


        if plane == "axial":
            midx = idxs[:, 2]
            x = tf.transpose(x, perm=[2, 0, 1])


        if plane == "combined":
            temp = {}
            for op in options[:-1]:
                temp[op] = structural_slice(x, y, op, n_slices)[0]
            x = temp

        if not plane == "combined":
            x = tf.squeeze(tf.gather_nd(x, midx.reshape(n_slices, 1, 1)), axis=1)
            x = tf.math.reduce_mean(x, axis=0)
            x = tf.expand_dims(x, axis=-1)
            x = tf.convert_to_tensor(x)
        return x, y
    else:
        raise ValueError("expected plane to be one of [sagittal, coronal, axial]")


if __name__ == "__main__":
    ROOTDIR = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/experiments/experiment_B/128/tfrecords_full'
    n_classes = 2
    global_batch_size = 8
    volume_shape = (128, 128, 128)
    ds = get_dataset(
        os.path.join(ROOTDIR, "data-train_*"),
        n_classes=n_classes,
        batch_size=global_batch_size,
        volume_shape=volume_shape,
        plane="coronal",
        shuffle_buffer_size=3,
    )
    
    import matplotlib.pyplot as plt

    # x, y = next(ds.as_numpy_operator())
    # print(x.shape, y)
    times = 0
    for x, y in ds.as_numpy_iterator():
        if times == 3:
            break
        print(x.shape, y)
        times += 1

        fig = plt.figure(figsize=(25, 8))

        for i in range(1, 9):
            fig.add_subplot(1,8, i)
            plt.imshow(x[i-1, :, :])


        print(ds)
# Out:
# (8, 128, 128, 1) [[0.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]]
# <RepeatDataset shapes: ((8, 128, 128, 1), (8, 1)), types: (tf.float32, tf.float32)>
# (8, 128, 128, 1) [[0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]]
# <RepeatDataset shapes: ((8, 128, 128, 1), (8, 1)), types: (tf.float32, tf.float32)>
# (8, 128, 128, 1) [[1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]]
# <RepeatDataset shapes: ((8, 128, 128, 1), (8, 1)), types: (tf.float32, tf.float32)>

# %%
# Std packages
import sys, os
import glob
import math

sys.path.append('..')

# Custom packages
import defacing
from defacing.models import modelN
# from defacing.dataloaders.dataset import get_dataset

# Tf packages
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.utils import class_weight
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    LearningRateScheduler,
    TensorBoard,
    EarlyStopping,
)
from tensorflow.keras import metrics
from tensorflow.keras import losses


def scheduler(epoch):
    if epoch < 3:
        return 0.001
    else:
        return 0.001 * tf.math.exp(0.1 * (10 - epoch))


def train(
    csv_path,
    model_save_path,
    tfrecords_path,
    volume_shape=(64, 64, 64),
    image_size=(64, 64),
    dropout=0.2,
    batch_size=16,
    n_slices=16,
    n_classes=2,
    n_epochs=15,
    percent=100,
    mode='CV',
):
    
    
    train_csv_path = os.path.join(csv_path, "training.csv")
    train_paths = pd.read_csv(train_csv_path)["X"].values
    train_labels = pd.read_csv(train_csv_path)["Y"].values
    
    if mode == 'CV':
        valid_csv_path = os.path.join(csv_path, "validation.csv")
        valid_paths = pd.read_csv(valid_csv_path)["X"].values
        valid_labels = pd.read_csv(valid_csv_path)["Y"].values
    
    weights = class_weight.compute_class_weight('balanced',
                                                np.unique(train_labels),
                                                train_labels)
    weights = dict(enumerate(weights))
    
    print(weights)
    
    planes = ["axial", "coronal", "sagittal", "combined"]
    

    global_batch_size = batch_size
    
    os.makedirs(model_save_path, exist_ok=True)
    cp_save_path = os.path.join(model_save_path, "weights")
    logdir_path = os.path.join(model_save_path, "tb_logs")
    metrics_path = os.path.join(model_save_path, "metrics")
    
    os.makedirs(metrics_path, exist_ok=True)
#     os.makedirs(logdir_path, exist_ok=True)
        
    for plane in planes:

        logdir = os.path.join(logdir_path, plane)
        os.makedirs(logdir, exist_ok=True)

        tbCallback = TensorBoard(log_dir=logdir)

        os.makedirs(os.path.join(cp_save_path, plane), exist_ok=True)

        model_checkpoint = ModelCheckpoint(
            os.path.join(cp_save_path, plane, "best-wts.h5"),
            monitor="val_loss",
            save_weights_only=True,
            mode="min",
        )

#         with strategy.scope():

        if not plane == "combined": 
            lr = 1e-3
            model = modelN.Submodel(
                input_shape=image_size,
                dropout=dropout,
                name=plane,
                include_top=True,
                weights=None,
            )
        else:
            lr = 5e-4
            model = modelN.CombinedClassifier(
                input_shape=image_size,
                dropout=dropout,
                trainable=True,
                wts_root=cp_save_path,
            )

        print("Submodel: ", plane)
#         print(model.summary())

        METRICS = [
            metrics.TruePositives(name="tp"),
            metrics.FalsePositives(name="fp"),
            metrics.TrueNegatives(name="tn"),
            metrics.FalseNegatives(name="fn"),
            metrics.BinaryAccuracy(name="accuracy"),
            metrics.Precision(name="precision"),
            metrics.Recall(name="recall"),
            metrics.AUC(name="auc"),
        ]

        model.compile(
            loss=tf.keras.losses.binary_crossentropy,
            optimizer=Adam(learning_rate=lr),
            metrics=METRICS,
        )

        print("GLOBAL BATCH SIZE: ", global_batch_size)

        dataset_train = get_dataset(
            file_pattern=os.path.join(tfrecords_path, 'data-train_*'),
            n_classes=n_classes,
            batch_size=global_batch_size,
            volume_shape=volume_shape,
            plane=plane,
            n_slices=n_slices,
            shuffle_buffer_size=global_batch_size,
        )
        
        steps_per_epoch = math.ceil(len(train_paths)/batch_size)
        print(steps_per_epoch)
        
        # CALLBACKS
        lrcallback = tf.keras.callbacks.LearningRateScheduler(scheduler)
        
        if mode == 'CV':
            earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
            
            dataset_valid = get_dataset(
                file_pattern=os.path.join(tfrecords_path, "data-valid_*"),
                n_classes=n_classes,
                batch_size=global_batch_size,
                volume_shape=volume_shape,
                plane=plane,
                n_slices=n_slices,
                shuffle_buffer_size=global_batch_size,
            )
            
            validation_steps = math.ceil(len(valid_paths)/batch_size)
            
            history = model.fit(
                dataset_train,
                epochs=n_epochs,
                steps_per_epoch=steps_per_epoch,
                validation_data=dataset_valid,
                validation_steps=validation_steps,
                callbacks=[tbCallback, model_checkpoint],
                class_weight = weights,
            )
            
            hist_df =  pd.DataFrame(history.history)
            
        else:
            earlystopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
            print(model.summary())
            print("Steps/Epoch: ", steps_per_epoch)
            history = model.fit(
                dataset_train,
                epochs=n_epochs,
                steps_per_epoch=steps_per_epoch,
                callbacks=[tbCallback, model_checkpoint, earlystopping],
                class_weight = weights,
            )
            
        hist_df =  pd.DataFrame(history.history)
        jsonfile = os.path.join(metrics_path, plane + '.json')
        
        with open(jsonfile, mode='w') as f:
            hist_df.to_json(f)
        
        del model
        K.clear_session()
        
    return history


# if __name__ == "__main__":
#     ROOTDIR = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/experiments/experiment_B/128'
#     csv_path = os.path.join(ROOTDIR, "csv_full")
#     model_save_path = os.path.join(ROOTDIR, "model_save_dir_full")
#     tfrecords_path = os.path.join(ROOTDIR, 'tfrecords_full')
    
#     history = train(
#     csv_path,
#     model_save_path,
#     tfrecords_path,
#     volume_shape=(128, 128, 128),
#     image_size=(128, 128),
#     mode='full'
#     )

# %%
# Std packages
import sys, os
import glob
import math
import tensorflow as tf

sys.path.append('..')

# Custom packages
# import defacing
# from defacing.models import modelN
# from defacing.dataloaders.dataset import get_dataset
# from defacing.training.training import train

for fold in range(8, 16):
    ROOTDIR = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/experiments/experiment_B/128'
    
    csv_path = os.path.join(ROOTDIR, 'csv_F15/train_test_fold_{}/csv'.format(fold))
    model_save_path = os.path.join(ROOTDIR, 'model_save_dir_F15/train_test_fold_{}'.format(fold))
    tfrecords_path = os.path.join(ROOTDIR, 'tfrecords_F15/tfrecords_fold_{}'.format(fold))
    
    history = train(
        csv_path,
        model_save_path,
        tfrecords_path,
        volume_shape = (128, 128, 128),
        image_size = (128, 128),
        mode = 'CV',
        n_slices=24,
        batch_size = 32,
    )
# Out:
# {0: 0.994092373791622, 1: 1.0059782608695653}
# Submodel:  axial
# GLOBAL BATCH SIZE:  32
# 58
# Epoch 1/15
# 58/58 [==============================] - 52s 533ms/step - loss: 1.4939 - tp: 408.2203 - fp: 57.9322 - tn: 424.3390 - fn: 68.9661 - accuracy: 0.8053 - precision: 0.8184 - recall: 0.7950 - auc: 0.8400 - val_loss: 2.2344 - val_tp: 76.0000 - val_fp: 84.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4750 - val_precision: 0.4750 - val_recall: 1.0000 - val_auc: 0.6541
# Epoch 2/15
# 58/58 [==============================] - 10s 174ms/step - loss: 0.0327 - tp: 465.3220 - fp: 6.5763 - tn: 482.5424 - fn: 5.0169 - accuracy: 0.9877 - precision: 0.9838 - recall: 0.9913 - auc: 0.9994 - val_loss: 4.1065 - val_tp: 81.0000 - val_fp: 79.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5063 - val_precision: 0.5063 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 3/15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0338 - tp: 470.5424 - fp: 5.4746 - tn: 477.2712 - fn: 6.1695 - accuracy: 0.9866 - precision: 0.9871 - recall: 0.9860 - auc: 0.9988 - val_loss: 4.1582 - val_tp: 82.0000 - val_fp: 78.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5125 - val_precision: 0.5125 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 4/15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0064 - tp: 483.9153 - fp: 1.1525 - tn: 474.3898 - fn: 0.0000e+00 - accuracy: 0.9987 - precision: 0.9974 - recall: 1.0000 - auc: 1.0000 - val_loss: 5.1020 - val_tp: 77.0000 - val_fp: 83.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4812 - val_precision: 0.4812 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 5/15
# 58/58 [==============================] - 10s 171ms/step - loss: 0.0015 - tp: 477.6949 - fp: 0.1017 - tn: 481.4576 - fn: 0.2034 - accuracy: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - val_loss: 6.5141 - val_tp: 78.0000 - val_fp: 82.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4875 - val_precision: 0.4875 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 6/15
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0113 - tp: 474.0339 - fp: 0.9831 - tn: 482.6441 - fn: 1.7966 - accuracy: 0.9957 - precision: 0.9961 - recall: 0.9952 - auc: 1.0000 - val_loss: 5.6203 - val_tp: 79.0000 - val_fp: 81.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4938 - val_precision: 0.4938 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 7/15
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0227 - tp: 476.1186 - fp: 2.2373 - tn: 475.8475 - fn: 5.2542 - accuracy: 0.9903 - precision: 0.9949 - recall: 0.9862 - auc: 0.9997 - val_loss: 7.1925 - val_tp: 78.0000 - val_fp: 82.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4875 - val_precision: 0.4875 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 8/15
# 58/58 [==============================] - 10s 171ms/step - loss: 0.0063 - tp: 473.1864 - fp: 0.6780 - tn: 485.0508 - fn: 0.5424 - accuracy: 0.9990 - precision: 0.9988 - recall: 0.9992 - auc: 1.0000 - val_loss: 5.1849 - val_tp: 84.0000 - val_fp: 76.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5250 - val_precision: 0.5250 - val_recall: 1.0000 - val_auc: 0.5329
# Epoch 9/15
# 58/58 [==============================] - 10s 172ms/step - loss: 2.9374e-04 - tp: 491.9322 - fp: 0.0000e+00 - tn: 467.5254 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 4.0051 - val_tp: 79.0000 - val_fp: 79.0000 - val_tn: 2.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5063 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6543
# Epoch 10/15
# 58/58 [==============================] - 10s 174ms/step - loss: 0.0013 - tp: 485.1017 - fp: 0.1017 - tn: 474.0000 - fn: 0.2542 - accuracy: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - val_loss: 0.0235 - val_tp: 81.0000 - val_fp: 2.0000 - val_tn: 77.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9875 - val_precision: 0.9759 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 11/15
# 58/58 [==============================] - 10s 174ms/step - loss: 0.0048 - tp: 476.2881 - fp: 1.5424 - tn: 479.8644 - fn: 1.7627 - accuracy: 0.9975 - precision: 0.9976 - recall: 0.9973 - auc: 1.0000 - val_loss: 0.3108 - val_tp: 83.0000 - val_fp: 11.0000 - val_tn: 66.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9312 - val_precision: 0.8830 - val_recall: 1.0000 - val_auc: 0.9805
# Epoch 12/15
# 58/58 [==============================] - 10s 174ms/step - loss: 0.0136 - tp: 466.4746 - fp: 2.4237 - tn: 488.3051 - fn: 2.2542 - accuracy: 0.9958 - precision: 0.9954 - recall: 0.9960 - auc: 0.9999 - val_loss: 0.3566 - val_tp: 64.0000 - val_fp: 2.0000 - val_tn: 78.0000 - val_fn: 16.0000 - val_accuracy: 0.8875 - val_precision: 0.9697 - val_recall: 0.8000 - val_auc: 0.9829
# Epoch 13/15
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0246 - tp: 478.6780 - fp: 1.9661 - tn: 477.5763 - fn: 1.2373 - accuracy: 0.9947 - precision: 0.9924 - recall: 0.9972 - auc: 0.9987 - val_loss: 16.5714 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 82.0000 - val_fn: 78.0000 - val_accuracy: 0.5125 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 14/15
# 58/58 [==============================] - 10s 175ms/step - loss: 0.0018 - tp: 481.9831 - fp: 0.2881 - tn: 476.9661 - fn: 0.2203 - accuracy: 0.9997 - precision: 0.9996 - recall: 0.9997 - auc: 1.0000 - val_loss: 0.0077 - val_tp: 76.0000 - val_fp: 0.0000e+00 - val_tn: 84.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 15/15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0045 - tp: 457.7797 - fp: 0.4068 - tn: 500.8814 - fn: 0.3898 - accuracy: 0.9995 - precision: 0.9994 - recall: 0.9995 - auc: 0.9997 - val_loss: 2.2574 - val_tp: 81.0000 - val_fp: 60.0000 - val_tn: 19.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.6250 - val_precision: 0.5745 - val_recall: 1.0000 - val_auc: 0.8228
# Submodel:  coronal
# GLOBAL BATCH SIZE:  32
# 58
# Epoch 1/15
# 58/58 [==============================] - 15s 180ms/step - loss: 2.7750 - tp: 360.1695 - fp: 128.4237 - tn: 343.7458 - fn: 127.1186 - accuracy: 0.6601 - precision: 0.6750 - recall: 0.6864 - auc: 0.7014 - val_loss: 0.8990 - val_tp: 82.0000 - val_fp: 78.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5125 - val_precision: 0.5125 - val_recall: 1.0000 - val_auc: 0.3515
# Epoch 2/15
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0834 - tp: 469.2712 - fp: 9.1186 - tn: 464.1525 - fn: 16.9153 - accuracy: 0.9711 - precision: 0.9831 - recall: 0.9604 - auc: 0.9941 - val_loss: 1.1254 - val_tp: 76.0000 - val_fp: 84.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4750 - val_precision: 0.4750 - val_recall: 1.0000 - val_auc: 0.3142
# Epoch 3/15
# 58/58 [==============================] - 9s 163ms/step - loss: 0.0363 - tp: 473.4576 - fp: 5.1356 - tn: 475.2203 - fn: 5.6441 - accuracy: 0.9893 - precision: 0.9883 - recall: 0.9903 - auc: 0.9989 - val_loss: 1.1556 - val_tp: 81.0000 - val_fp: 79.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5063 - val_precision: 0.5063 - val_recall: 1.0000 - val_auc: 0.2543
# Epoch 4/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0271 - tp: 461.2542 - fp: 2.1695 - tn: 489.5593 - fn: 6.4746 - accuracy: 0.9901 - precision: 0.9943 - recall: 0.9847 - auc: 0.9992 - val_loss: 1.3823 - val_tp: 78.0000 - val_fp: 82.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4875 - val_precision: 0.4875 - val_recall: 1.0000 - val_auc: 0.4619
# Epoch 5/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0130 - tp: 469.0508 - fp: 1.9153 - tn: 486.4237 - fn: 2.0678 - accuracy: 0.9968 - precision: 0.9969 - recall: 0.9965 - auc: 0.9999 - val_loss: 1.1899 - val_tp: 77.0000 - val_fp: 83.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4812 - val_precision: 0.4812 - val_recall: 1.0000 - val_auc: 0.5614
# Epoch 6/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0149 - tp: 476.2373 - fp: 2.2203 - tn: 479.5254 - fn: 1.4746 - accuracy: 0.9965 - precision: 0.9953 - recall: 0.9976 - auc: 0.9999 - val_loss: 1.9297 - val_tp: 81.0000 - val_fp: 79.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5063 - val_precision: 0.5063 - val_recall: 1.0000 - val_auc: 0.8059
# Epoch 7/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0168 - tp: 481.7458 - fp: 1.4407 - tn: 474.3729 - fn: 1.8983 - accuracy: 0.9954 - precision: 0.9949 - recall: 0.9964 - auc: 0.9999 - val_loss: 1.6954 - val_tp: 81.0000 - val_fp: 72.0000 - val_tn: 7.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5500 - val_precision: 0.5294 - val_recall: 1.0000 - val_auc: 0.9162
# Epoch 8/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0111 - tp: 472.5763 - fp: 2.4237 - tn: 481.4068 - fn: 3.0508 - accuracy: 0.9941 - precision: 0.9942 - recall: 0.9940 - auc: 0.9999 - val_loss: 1.1909 - val_tp: 79.0000 - val_fp: 56.0000 - val_tn: 25.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.6500 - val_precision: 0.5852 - val_recall: 1.0000 - val_auc: 0.9430
# Epoch 9/15
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0048 - tp: 477.6780 - fp: 0.0000e+00 - tn: 481.7797 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.6070 - val_tp: 78.0000 - val_fp: 37.0000 - val_tn: 45.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.7688 - val_precision: 0.6783 - val_recall: 1.0000 - val_auc: 0.9864
# Epoch 10/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0017 - tp: 494.1186 - fp: 0.0000e+00 - tn: 464.7288 - fn: 0.6102 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9990 - auc: 1.0000 - val_loss: 0.2067 - val_tp: 81.0000 - val_fp: 13.0000 - val_tn: 66.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9187 - val_precision: 0.8617 - val_recall: 1.0000 - val_auc: 0.9989
# Epoch 11/15
# 58/58 [==============================] - 10s 166ms/step - loss: 0.0014 - tp: 472.6102 - fp: 0.0000e+00 - tn: 486.8475 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0828 - val_tp: 75.0000 - val_fp: 6.0000 - val_tn: 78.0000 - val_fn: 1.0000 - val_accuracy: 0.9563 - val_precision: 0.9259 - val_recall: 0.9868 - val_auc: 0.9984
# Epoch 12/15
# 58/58 [==============================] - 9s 163ms/step - loss: 4.9773e-04 - tp: 476.9153 - fp: 0.0000e+00 - tn: 482.5424 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0493 - val_tp: 81.0000 - val_fp: 1.0000 - val_tn: 76.0000 - val_fn: 2.0000 - val_accuracy: 0.9812 - val_precision: 0.9878 - val_recall: 0.9759 - val_auc: 0.9987
# Epoch 13/15
# 58/58 [==============================] - 9s 164ms/step - loss: 8.3598e-04 - tp: 466.9322 - fp: 0.0000e+00 - tn: 492.5254 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.
- fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.3311 - val_tp: 78.0000 - val_fp: 19.0000 - val_tn: 63.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8813 - val_precision: 0.8041 - val_recall: 1.0000 - val_auc: 0.9934
# Epoch 10/15
# 58/58 [==============================] - 8s 138ms/step - loss: 1.9229e-04 - tp: 479.1017 - fp: 0.0000e+00 - tn: 480.3559 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0453 - val_tp: 76.0000 - val_fp: 3.0000 - val_tn: 81.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9812 - val_precision: 0.9620 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 11/15
# 58/58 [==============================] - 8s 142ms/step - loss: 8.8577e-05 - tp: 467.3051 - fp: 0.0000e+00 - tn: 492.1525 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 7.6203e-04 - val_tp: 78.0000 - val_fp: 0.0000e+00 - val_tn: 82.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 12/15
# 58/58 [==============================] - 8s 139ms/step - loss: 1.3004e-04 - tp: 470.8136 - fp: 0.0000e+00 - tn: 488.6441 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.9041e-04 - val_tp: 83.0000 - val_fp: 0.0000e+00 - val_tn: 77.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 13/15
# 58/58 [==============================] - 8s 139ms/step - loss: 9.6856e-05 - tp: 482.5932 - fp: 0.0000e+00 - tn: 476.8644 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 6.0350e-04 - val_tp: 78.0000 - val_fp: 0.0000e+00 - val_tn: 82.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 14/15
# 58/58 [==============================] - 8s 140ms/step - loss: 6.2947e-05 - tp: 472.6102 - fp: 0.0000e+00 - tn: 486.8475 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 8.1884e-04 - val_tp: 86.0000 - val_fp: 0.0000e+00 - val_tn: 74.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 15/15
# 58/58 [==============================] - 8s 139ms/step - loss: 6.4879e-05 - tp: 483.0339 - fp: 0.0000e+00 - tn: 476.4237 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 8.7975e-04 - val_tp: 80.0000 - val_fp: 0.0000e+00 - val_tn: 80.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# axial (InputLayer)              [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# sagittal (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# coronal (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 8)  80          axial[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 8)  80          sagittal[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 8)  80          coronal[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 8)  32          conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 8)  32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 8)  32          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 8)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 8)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 8)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 8)  584         activation[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 8)  584         activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 8)  584         activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 8)  32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 8)  32          conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 8)  32          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 8)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 8)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 8)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 8)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 8)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 8)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 16)   1168        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 16)   2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 32)   9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 8192)         0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8192)         0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          2097408     add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# output_node (Dense)             (None, 1)            257         dropout[0][0]
# ==================================================================================================
# Total params: 2,153,129
# Trainable params: 2,152,457
# Non-trainable params: 672
# __________________________________________________________________________________________________
# None
# Submodel:  combined
# GLOBAL BATCH SIZE:  32
# 58
# Epoch 1/15
# 58/58 [==============================] - 20s 232ms/step - loss: 4.4299 - tp: 326.1525 - fp: 151.6949 - tn: 333.8136 - fn: 147.7966 - accuracy: 0.6341 - precision: 0.6240 - recall: 0.6300 - auc: 0.6495 - val_loss: 0.6648 - val_tp: 84.0000 - val_fp: 76.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5250 - val_precision: 0.5250 - val_recall: 1.0000 - val_auc: 0.8895
# Epoch 2/15
# 58/58 [==============================] - 12s 214ms/step - loss: 0.0597 - tp: 470.9492 - fp: 6.9831 - tn: 476.5593 - fn: 4.9661 - accuracy: 0.9849 - precision: 0.9829 - recall: 0.9874 - auc: 0.9968 - val_loss: 0.7860 - val_tp: 79.0000 - val_fp: 81.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4938 - val_precision: 0.4938 - val_recall: 1.0000 - val_auc: 0
15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0130 - tp: 472.2712 - fp: 1.5424 - tn: 483.5085 - fn: 2.1356 - accuracy: 0.9967 - precision: 0.9970 - recall: 0.9964 - auc: 0.9999 - val_loss: 2.1770 - val_tp: 82.0000 - val_fp: 70.0000 - val_tn: 8.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5625 - val_precision: 0.5395 - val_recall: 1.0000 - val_auc: 0.8077
# Epoch 11/15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0376 - tp: 465.7797 - fp: 4.7627 - tn: 485.1695 - fn: 3.7458 - accuracy: 0.9884 - precision: 0.9863 - recall: 0.9895 - auc: 0.9978 - val_loss: 0.4052 - val_tp: 83.0000 - val_fp: 25.0000 - val_tn: 52.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.8438 - val_precision: 0.7685 - val_recall: 1.0000 - val_auc: 0.9935
# Epoch 12/15
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0056 - tp: 480.9661 - fp: 0.9831 - tn: 476.2034 - fn: 1.3051 - accuracy: 0.9983 - precision: 0.9987 - recall: 0.9980 - auc: 1.0000 - val_loss: 1.0134 - val_tp: 81.0000 - val_fp: 48.0000 - val_tn: 31.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.7000 - val_precision: 0.6279 - val_recall: 1.0000 - val_auc: 0.9430
# Epoch 13/15
# 58/58 [==============================] - 10s 175ms/step - loss: 0.0127 - tp: 485.3051 - fp: 4.0169 - tn: 466.7627 - fn: 3.3729 - accuracy: 0.9935 - precision: 0.9927 - recall: 0.9946 - auc: 0.9999 - val_loss: 0.0048 - val_tp: 84.0000 - val_fp: 0.0000e+00 - val_tn: 76.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 14/15
# 58/58 [==============================] - 10s 170ms/step - loss: 0.0072 - tp: 464.1864 - fp: 1.2203 - tn: 492.7966 - fn: 1.2542 - accuracy: 0.9980 - precision: 0.9978 - recall: 0.9980 - auc: 1.0000 - val_loss: 0.9353 - val_tp: 52.0000 - val_fp: 0.0000e+00 - val_tn: 73.0000 - val_fn: 35.0000 - val_accuracy: 0.7812 - val_precision: 1.0000 - val_recall: 0.5977 - val_auc: 0.9425
# Epoch 15/15
# 58/58 [==============================] - 10s 172ms/step - loss: 0.0062 - tp: 474.8475 - fp: 1.0339 - tn: 481.7119 - fn: 1.8644 - accuracy: 0.9975 - precision: 0.9983 - recall: 0.9968 - auc: 1.0000 - val_loss: 0.2905 - val_tp: 82.0000 - val_fp: 10.0000 - val_tn: 68.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9375 - val_precision: 0.8913 - val_recall: 1.0000 - val_auc: 0.9872
# Submodel:  coronal
# GLOBAL BATCH SIZE:  32
# 58
# Epoch 1/15
# 58/58 [==============================] - 15s 179ms/step - loss: 1.9383 - tp: 384.3898 - fp: 79.4237 - tn: 410.3220 - fn: 85.3220 - accuracy: 0.7644 - precision: 0.7520 - recall: 0.7442 - auc: 0.7997 - val_loss: 0.6762 - val_tp: 77.0000 - val_fp: 79.0000 - val_tn: 4.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5063 - val_precision: 0.4936 - val_recall: 1.0000 - val_auc: 0.8177
# Epoch 2/15
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0561 - tp: 469.3051 - fp: 5.1017 - tn: 477.4407 - fn: 7.6102 - accuracy: 0.9858 - precision: 0.9871 - recall: 0.9837 - auc: 0.9958 - val_loss: 1.1353 - val_tp: 87.0000 - val_fp: 73.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5437 - val_precision: 0.5437 - val_recall: 1.0000 - val_auc: 0.8515
# Epoch 3/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0201 - tp: 473.7966 - fp: 3.1186 - tn: 479.3051 - fn: 3.2373 - accuracy: 0.9939 - precision: 0.9942 - recall: 0.9935 - auc: 0.9998 - val_loss: 2.6252 - val_tp: 76.0000 - val_fp: 84.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4750 - val_precision: 0.4750 - val_recall: 1.0000 - val_auc: 0.7939
# Epoch 4/15
# 58/58 [==============================] - 10s 166ms/step - loss: 0.0134 - tp: 465.1525 - fp: 1.8814 - tn: 490.6949 - fn: 1.7288 - accuracy: 0.9948 - precision: 0.9928 - recall: 0.9965 - auc: 0.9999 - val_loss: 4.1359 - val_tp: 79.0000 - val_fp: 81.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4938 - val_precision: 0.4938 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 5/15
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0081 - tp: 464.9153 - fp: 0.0000e+00 - tn: 492.0847 - fn: 2.4576 - accuracy: 0.9968 - precision: 1.0000 - recall: 0.9932 - auc: 1.0000 - val_loss: 6.3721 - val_tp: 79.0000 - val_fp: 81.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4938 - val_precision: 0.4938 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 6/15
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0093 - tp: 472.8814 - fp: 3.2203 - tn: 481.1017 - fn: 2.2542 - accuracy: 0.9939 - precision: 0.9913 - recall: 0.9966 - auc: 1.0000 - val_loss: 2.7682 - val_tp: 75.0000 - val_fp: 84.0000 - val_tn: 1.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.4750 - val_precision: 0.4717 - val_recall: 1.0000 - val_auc: 0.7807
# Epoch 7/15
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0042 - tp: 486.3220 - fp: 0.7797 - tn: 470.9661 - fn: 1.3898 - accuracy: 0.9981 - precision: 0.9985 - recall: 0.9977 - auc: 1.0000 - val_loss: 6.1677 - val_tp: 80.0000 - val_fp: 80.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5000
# Epoch 8/15
# ...
# conv2d_8 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 16)   1168        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 16)   2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 32)   9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 8192)         0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8192)         0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          2097408     add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# output_node (Dense)             (None, 1)            257         dropout[0][0]
# ==================================================================================================
# Total params: 2,153,129
# Trainable params: 2,152,457
# Non-trainable params: 672
# __________________________________________________________________________________________________
# None
# Submodel:  combined
# GLOBAL BATCH SIZE:  32
# 58
# Epoch 1/15
# 58/58 [==============================] - 20s 234ms/step - loss: 2.2467 - tp: 357.2373 - fp: 115.0169 - tn: 366.7966 - fn: 120.4068 - accuracy: 0.6991 - precision: 0.6910 - recall: 0.6767 - auc: 0.7325 - val_loss: 0.9463 - val_tp: 74.0000 - val_fp: 86.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4625 - val_precision: 0.4625 - val_recall: 1.0000 - val_auc: 0.9267
# Epoch 2/15
# 58/58 [==============================] - 12s 214ms/step - loss: 0.0283 - tp: 470.8814 - fp: 5.7627 - tn: 479.0678 - fn: 3.7458 - accuracy: 0.9884 - precision: 0.9841 - recall: 0.9926 - auc: 0.9996 - val_loss: 1.1522 - val_tp: 79.0000 - val_fp: 81.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.4938 - val_precision: 0.4938 - val_recall: 1.0000 - val_auc: 0.9824
# Epoch 3/15
# 58/58 [==============================] - 12s 215ms/step - loss: 0.0152 - tp: 494.0847 - fp: 1.5763 - tn: 461.7458 - fn: 2.0508 - accuracy: 0.9952 - precision: 0.9972 - recall: 0.9938 - auc: 1.0000 - val_loss: 1.6166 - val_tp: 77.0000 - val_fp: 83.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.
0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 15/15
# 58/58 [==============================] - 12s 214ms/step - loss: 1.9826e-04 - tp: 474.2034 - fp: 0.0000e+00 - tn: 485.2542 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0035 - val_tp: 79.0000 - val_fp: 0.0000e+00 - val_tn: 81.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000

# %%
pip install -U tensorboard_plugin_profile
# Out:
# Collecting tensorboard_plugin_profile
#   Downloading tensorboard_plugin_profile-2.4.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 1.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.15.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (3.14.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.0.1)
# Collecting gviz-api>=1.9.0
#   Downloading gviz_api-1.9.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (52.0.0)
# Installing collected packages: gviz-api, tensorboard-plugin-profile
# Successfully installed gviz-api-1.9.0 tensorboard-plugin-profile-2.4.0
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if not device_name:
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import sys, os
sys.path.append('..')
from defacing.models.modelN import CombinedClassifier
# from defacing.dataloaders.dataset import get_dataset


# Tf packages
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics
from tensorflow.keras import losses

def inference(tfrecords_path, weights_path, wts_root):
    
    model = CombinedClassifier(
        input_shape=(128, 128), dropout=0.4, wts_root=wts_root, trainable=False)
    
    model.load_weights(os.path.abspath(weights_path))
    model.trainable = False
    
    dataset_test = get_dataset(
        file_pattern=os.path.join(tfrecords_path, "data-test_*"),
        n_classes=2,
        batch_size=128,
        volume_shape=(128, 128, 128),
        plane='combined',
        mode='test'
    )

    METRICS = [
        metrics.TruePositives(name="tp"),
        metrics.FalsePositives(name="fp"),
        metrics.TrueNegatives(name="tn"),
        metrics.FalseNegatives(name="fn"),
        metrics.BinaryAccuracy(name="accuracy"),
        metrics.Precision(name="precision"),
        metrics.Recall(name="recall"),
        metrics.AUC(name="auc"),
    ]
    
    model.compile(
        loss=tf.keras.losses.binary_crossentropy,
        optimizer=Adam(learning_rate=1e-3),
        metrics=METRICS,
    )
    
    model.evaluate(dataset_test)
    predictions = (model.predict(dataset_test) > 0.5).astype(int)
    
    
    return predictions

if __name__ == "__main__":
    ROOTDIR = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/test_ixi'
    tfrecords_path = os.path.join(ROOTDIR, "tfrecords")
    weights_path = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/experiments/experiment_B/128/model_save_dir_full/weights/combined/best-wts.h5'
    wts_root = '/tf/shank/HDDLinux/Stanford/data/mriqc-shared/experiments/experiment_B/128/model_save_dir_full/weights'
    inference(tfrecords_path, weights_path, wts_root)
# Out:
# Model: "model_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# axial (InputLayer)              [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# sagittal (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# coronal (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 128, 128, 8)  80          axial[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 128, 128, 8)  80          sagittal[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 128, 128, 8)  80          coronal[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 128, 128, 8)  32          conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 128, 128, 8)  32          conv2d_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 128, 128, 8)  32          conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 128, 128, 8)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 128, 128, 8)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 128, 128, 8)  0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 128, 128, 8)  584         activation_144[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 128, 128, 8)  584         activation_150[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 128, 128, 8)  584         activation_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 128, 128, 8)  32          conv2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 128, 128, 8)  32          conv2d_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 128, 128, 8)  32          conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 128, 128, 8)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 128, 128, 8)  0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 128, 128, 8)  0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_72 (MaxPooling2D) (None, 64, 64, 8)    0           activation_145[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_75 (MaxPooling2D) (None, 64, 64, 8)    0           activation_151[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_78 (MaxPooling2D) (None, 64, 64, 8)    0           activation_157[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 64, 64, 16)   64          conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 64, 64, 16)   64          conv2d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 64, 64, 16)   64          conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 64, 64, 16)   0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 64, 64, 16)   0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 64, 64, 16)   0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 64, 64, 16)   2320        activation_146[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 64, 64, 16)   2320        activation_152[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 64, 64, 16)   2320        activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 64, 64, 16)   64          conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 64, 64, 16)   64          conv2d_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 64, 64, 16)   64          conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 64, 64, 16)   0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 64, 64, 16)   0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 64, 64, 16)   0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_73 (MaxPooling2D) (None, 32, 32, 16)   0           activation_147[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_76 (MaxPooling2D) (None, 32, 32, 16)   0           activation_153[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_79 (MaxPooling2D) (None, 32, 32, 16)   0           activation_159[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 32, 32, 32)   128         conv2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 32, 32, 32)   128         conv2d_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 32, 32, 32)   128         conv2d_160[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 32, 32, 32)   0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 32, 32, 32)   0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 32, 32, 32)   0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 32, 32, 32)   9248        activation_148[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 32, 32, 32)   9248        activation_154[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 32, 32, 32)   9248        activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 32, 32, 32)   128         conv2d_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 32, 32, 32)   128         conv2d_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 32, 32, 32)   128         conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 32, 32, 32)   0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 32, 32, 32)   0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 32, 32, 32)   0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_74 (MaxPooling2D) (None, 16, 16, 32)   0           activation_149[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_77 (MaxPooling2D) (None, 16, 16, 32)   0           activation_155[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_80 (MaxPooling2D) (None, 16, 16, 32)   0           activation_161[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 8192)         0           max_pooling2d_74[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 8192)         0           max_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 8192)         0           max_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8192)         0           flatten_24[0][0]
#                                                                  flatten_25[0][0]
#                                                                  flatten_26[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          2097408     add_4[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# output_node (Dense)             (None, 1)            257         dropout_16[0][0]
# ==================================================================================================
# Total params: 2,153,129
# Trainable params: 2,115,929
# Non-trainable params: 37,200
# __________________________________________________________________________________________________
# None
# 9/9 [==============================] - 6s 527ms/step - loss: 0.0593 - tp: 344.9000 - fp: 6.1000 - tn: 336.4000 - fn: 3.8000 - accuracy: 0.9853 - precision: 0.9824 - recall: 0.9889 - auc: 0.9961

# %%
import matplotlib.pyplot as plt

# x, y = next(ds.as_numpy_operator())
# print(x.shape, y)
times = 0
for x, y in ds.as_numpy_iterator():
    if times == 3:
        break
    print(x.shape, y)
    times += 1
    
    fig = plt.figure(figsize=(25, 8))
    
    for i in range(1, 9):
        fig.add_subplot(1,8, i)
        plt.imshow(x[i-1, :, :])
    
#     all_imgs = []
#     for i in range(len(batch_predictions)):
#         if batch_predictions.flatten()[i] != y.flatten()[i].astype(int):
#             incorr += 1
#             print("Predicted: ",batch_predictions.flatten()[i], "Actual: ", y.flatten()[i].astype(int))
#         else:
#             corr += 1
            
#             fig = plt.figure(figsize=(25, 8))
#             rows, cols = 3, 16
            
#             for i in range(1, cols*rows + 1):
# #                 if i/cols == 1:
# #                     use = x['coronal']
# #                 if i/cols == 2:
# #                     use = x['sagittal']
                    
#                 fig.add_subplot(rows, cols, i)
                
#                 plt.imshow(use[(i-1)%cols,:,:, 0])


#             plt.show()
